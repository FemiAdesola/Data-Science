# %% [markdown]
# <a href="https://colab.research.google.com/github/FemiAdesola/Data-Science/blob/main/WhatApp_data_Analsis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <INS>**WHATAPP DATA ANALYSIS**

# %% [markdown]
# ## <ins>**Import libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#  To mount the drive using the following commands:

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
whatsaup_df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Whatuptext1.tsv', sep = '\t')

# %%
whatsaup_df.head()
# Out:
#           date          Name  \
# 0  09 May 2024        Church
# 1  09 May 2024          INda
# 2  09 May 2024  Sis Joy Ehis
# 3  09 May 2024   Bro Godfrey
# 4  09 May 2024  Too Faithful
#
#                                             Messages  feedback
# 0  Glory be to God Almighty 🙏 it's another day to...       1.0
# 1                                 Happy birthday sir       1.0
# 2                                 Happy birthday sir       1.0
# 3  Happy birthday  to you Sir…. Chears to great l...       1.0
# 4                                 Happy birthday sir       1.0

# %%
# @title length

from matplotlib import pyplot as plt
whatsaup_df['length'].plot(kind='line', figsize=(8, 4), title='length')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
whatsaup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      60 non-null     object
#  1   Name      60 non-null     object
#  2   Messages  60 non-null     object
#  3   feedback  59 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 2.0+ KB

# %%
whatsaup_df['Messages']
# Out:
# 0     Glory be to God Almighty 🙏 it's another day to...
# 1                                    Happy birthday sir
# 2                                    Happy birthday sir
# 3     Happy birthday  to you Sir…. Chears to great l...
# 4                                    Happy birthday sir
# 5                                    Happy birthday sir
# 6                                        Happy birthday
# 7     Hbd to you sir wishing you age gracefully in life
# 8                                    Happy birthday sir
# 9     Happy birthday sir! Wishing you a year full of...
# 10                                       Happy birthday
# 11    Happy birthday bro more years of celebration 🍾...
# 12    Happy birthday my love, caring hubby! may this...
# 13                           Happy birthday Sir, wullnp
# 14                          Happy birthday , more grace
# 15                                   Happy birthday sir
# 16                                       Happy birthday
# ...

# %%
sns.heatmap(whatsaup_df.isnull(), yticklabels = False, cbar = False, cmap="Reds")
# Out:
# <Axes: >

# %%
# Let's get the length of the messages and for adding another columns call length
whatsaup_df['length'] = whatsaup_df['Messages'].str.len()

# %%
whatsaup_df.head()
# Out:
#           date          Name  \
# 0  09 May 2024        Church
# 1  09 May 2024          INda
# 2  09 May 2024  Sis Joy Ehis
# 3  09 May 2024   Bro Godfrey
# 4  09 May 2024  Too Faithful
#
#                                             Messages  feedback  length
# 0  Glory be to God Almighty 🙏 it's another day to...       1.0     158
# 1                                 Happy birthday sir       1.0      18
# 2                                 Happy birthday sir       1.0      18
# 3  Happy birthday  to you Sir…. Chears to great l...       1.0      66
# 4                                 Happy birthday sir       1.0      18

# %%
whatsaup_df['length'].plot(bins=100, kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
whatsaup_df.length.describe()
# Out:
# count     60.000000
# mean     172.416667
# std      203.870039
# min       14.000000
# 25%       25.750000
# 50%      109.500000
# 75%      197.500000
# max      931.000000
# Name: length, dtype: float64

# %%
# For making massive paragraph or sentences
sentences = whatsaup_df['Messages'].tolist()

# %%
sentences
# Out:
# ["Glory be to God Almighty 🙏 it's another day to thank the Lord for another celebrant today @\u2068FM\u2069 \u2069 . Please family, let's celebrate him with your prayers 🙏🏻🥳🥳🥳",
#  'Happy birthday sir',
#  'Happy birthday sir',
#  'Happy birthday  to you Sir…. Chears to great life. Congratulations',
#  'Happy birthday sir',
#  'Happy birthday sir',
#  'Happy birthday',
#  'Hbd to you sir wishing you age gracefully in life',
#  'Happy birthday sir',
#  'Happy birthday sir! Wishing you a year full of divine experiences, happiness, joy, blessings, peace of mind and in sound health in Jesus. 🙏🏾',
#  'Happy birthday',
#  'Happy birthday bro more years of celebration 🍾 in Jesus name Amen 🙏',
#  'Happy birthday my love, caring hubby! may this year be the one you chase your dreams and catch them. I pray that God fills your life with infinite joy and gives you all the success you deserve❤️🎈🎊💐',
#  'Happy birthday Sir, wullnp',
#  'Happy birthday , more grace',
#  'Happy birthday sir',
# ...

# %%
len(sentences)
# Out:
# 60

# %%
# For joining the sentences
sentences_as_one_string = " ".join(map(str, sentences))

# %%
sentences_as_one_string
# Out:
# 'Glory be to God Almighty 🙏 it\'s another day to thank the Lord for another celebrant today @\u2068FM\u2069 \u2069 . Please family, let\'s celebrate him with your prayers 🙏🏻🥳🥳🥳 Happy birthday sir Happy birthday sir Happy birthday  to you Sir…. Chears to great life. Congratulations Happy birthday sir Happy birthday sir Happy birthday Hbd to you sir wishing you age gracefully in life Happy birthday sir Happy birthday sir! Wishing you a year full of divine experiences, happiness, joy, blessings, peace of mind and in sound health in Jesus. 🙏🏾 Happy birthday Happy birthday bro more years of celebration 🍾 in Jesus name Amen 🙏 Happy birthday my love, caring hubby! may this year be the one you chase your dreams and catch them. I pray that God fills your life with infinite joy and gives you all the success you deserve❤️🎈🎊💐 Happy birthday Sir, wullnp Happy birthday , more grace Happy birthday sir Happy birthday Happy birthday sir. May the joy of the lord never depart from your life. 🙏🏼 many ha
# ...

# %%
from wordcloud import WordCloud
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
w = WordCloud()
stop_words = list(w.stopwords)
custom_stop_words = ['Jesus', 'brother', 'Happy','enemy', 'wife', 'cut', 'FM', 'days', 'family', 'man','children','hot', 'pick','sick', 'sake', 'deads','done','things', 'done', 'sister', 'Evelyn', 'us','please', 'dad', 'fall', 'pastor', 'labour', 'everything', 'thee', 'christ', 'mighty', 'land', 'thing', 'Almighty', 'name', 'birthday', 'many','every','Amen' ,'long', 'bring', 'uncle', 'bro', 'celebrate', 'new', 'age', 'thank', 'wishing', 'God', 'Femi', 'prayer', 'Sir', 'Lord', 'May', 'year', 'life', 'Jesu', 'Will', 'day', 'power', 'years']
stop_words = set(stop_words + custom_stop_words)

wordcloud = WordCloud(background_color="black", width=1600,height=800, stopwords=stop_words).generate(sentences_as_one_string)
plt.figure(figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1599.5, 799.5, -0.5)

# %%
#plt.figure(figsize=(15,15))
#plt.imshow(WordCloud().generate(sentences_as_one_string), interpolation="bilinear")
#plt.axis("off")
#plt.show()

# %%
#import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#from nltk.corpus import stopwords
#stopwords.words('english')

# %%
from PIL import Image

# %%
mask = np.array(Image.open("/content/drive/My Drive/Colab Notebooks/world.png"))

# %%
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
from tkinter import Message
from wordcloud import ImageColorGenerator




wordcloud = WordCloud(background_color="black", width=1600,height=800, stopwords=stop_words, mask=mask).generate(sentences_as_one_string)

# create coloring from image
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=(20,10), facecolor='w')
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 2057.5, 1261.5, -0.5)
